# %% [markdown]
# # nnids_pipeline — Quick Run
#
# Questo notebook riproduce esattamente il flusso manuale:
# ```
# git clone ...
# bash setup.sh
# source .venv/bin/activate
# python main.py
# ```
#
# > Testato su **Linux** (Google Colab / Jupyter locale).
# > Richiede `sudo` per installare le dipendenze di sistema (Java, unrar).

# %% [markdown]
# ## 1. Clone del repository

# %%
# !git clone https://github.com/devedale/cic-ids-2018-labeling.git

# %% [markdown]
# ## 2. Setup ambiente
#
# `setup.sh` installa le dipendenze di sistema, crea `.venv` (se non esiste),
# installa i pacchetti Python e fa uno smoke-test PySpark.

# %%
# !cd cic-ids-2018-labeling && bash setup.sh

# %% [markdown]
# ## 3. Esecuzione della pipeline
#
# Su Colab `source .venv/bin/activate` non è disponibile (venv saltato da `setup.sh`),
# quindi usiamo `python` di sistema. In locale si usa `.venv/bin/python`.
# In entrambi i casi il risultato è identico a `source .venv/bin/activate && python main.py`.

# %%
import subprocess, sys, os
repo = "cic-ids-2018-labeling"
python = os.path.join(repo, ".venv", "bin", "python") if os.path.exists(os.path.join(repo, ".venv")) else sys.executable
result = subprocess.run([python, "main.py"], cwd=repo)
sys.exit(result.returncode)
